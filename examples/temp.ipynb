# %%
import topotoolbox as topo

# %%
dem = topo.load_dem('perfectworld')

# %%
gradient = dem.gradient8()
gradient.show()

# %%
dem.gradient8(unit='percent').show()

# %%
dem.gradient8(unit='sine').show()

# %%
dem.gradient8(unit='degree').show()

# %%
dem.gradient8(unit='radian').show()
