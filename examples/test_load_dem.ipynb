# %% [markdown]
# ## test load dem

# %%
import topotoolbox as topo

# %%
print(topo.get_dem_names())
# Out:
# ['kedarnath', 'kunashiri', 'perfectworld', 'taalvolcano', 'taiwan', 'tibet']

# %%
dem = topo.load_dem("/home/bgailleton/Desktop/data/green_river_1.tif")
dem.info()
print(topo.get_cache_contents())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 dem = topo.load_dem("/home/bgailleton/Desktop/data/green_river_1.tif")
#       2 dem.info()
#       3 print(topo.get_cache_contents())
#
# File ~/mambaforge/envs/dagger/lib/python3.10/site-packages/topotoolbox/utils.py:179, in load_dem(dem, cache)
#     176 if dem not in get_dem_names():
#     177     err = ("Selected DEM has to be selected from the provided examples." +
#     178            " See which DEMs are available by using 'get_dem_names()'.")
# --> 179     raise ValueError(err)
#     181 url = f"{DEM_SOURCE}/{dem}.tif"
#     183 if cache:
#
# ValueError: Selected DEM has to be selected from the provided examples. See which DEMs are available by using 'get_dem_names()'.

# %% [markdown]
# Run topo.clear_cache() do remove all files in the TopoToolbox cache.

# %%
help(dem)
# Out:
# Help on GridObject in module topotoolbox.grid_object object:
#
# class GridObject(builtins.object)
#  |  GridObject() -> None
#  |
#  |  A class containing all information of a Digital Elevation Model (DEM).
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, other)
#  |
#  |  __and__(self, other)
#  |
#  |  __array__(self)
#  |
#  |  __div__(self, other)
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __ge__(self, other)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, index)
#  |
#  |  __gt__(self, other)
#  |      Return self>value.
#  |
#  |  __init__(self) -> None
#  |      Initialize a GridObject instance.
#  |
#  |  __iter__(self)
#  |
#  |  __le__(self, other)
#  |      Return self<=value.
#  |
#  |  __len__(self)
#  |
#  |  __lt__(self, other)
#  |      Return self<value.
#  |
#  |  __mul__(self, other)
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __or__(self, other)
#  |      Return self|value.
#  |
# ...

# %%
help(topo.grid_object)
# Out:
# Help on module topotoolbox.grid_object in topotoolbox:
#
# NAME
#     topotoolbox.grid_object - This module contains the GridObject class.
#
# CLASSES
#     builtins.object
#         GridObject
#
#     class GridObject(builtins.object)
#      |  GridObject() -> None
#      |
#      |  A class containing all information of a Digital Elevation Model (DEM).
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, other)
#      |
#      |  __and__(self, other)
#      |
#      |  __array__(self)
#      |
#      |  __div__(self, other)
#      |
#      |  __eq__(self, other)
#      |      Return self==value.
#      |
#      |  __ge__(self, other)
#      |      Return self>=value.
#      |
#      |  __getitem__(self, index)
#      |
#      |  __gt__(self, other)
#      |      Return self>value.
#      |
#      |  __init__(self) -> None
#      |      Initialize a GridObject instance.
#      |
#      |  __iter__(self)
#      |
#      |  __le__(self, other)
# ...
