# %%
import topotoolbox as tt3
import numpy as np
import matplotlib.pyplot as plt

# %%
dem = tt3.load_dem('perfectworld')
p, index = dem.prominence(100.0)

plt.subplot()
plt.imshow(dem, cmap='terrain')
plt.scatter(index[1], index[0], c=p, cmap='viridis', edgecolors='red', alpha=0.7)
plt.show()

# %%
print(p)
print(index)
496.364558647461
124.990873928957
124.465721152812
119.039632141238
116.354615334518
115.462374317063
109.966179609838
109.620003312409
105.202409794586
98.2297876218699
# Out:
# [496.36456  124.990875 124.46573  119.03964  116.354614 115.46237
#  109.96619  109.619995 105.20239   98.2298  ]
# (array([549, 930, 813, 508, 107, 449, 779, 299, 706, 738]), array([515, 127, 879, 307, 428, 841, 250, 815, 897, 381]))
# 98.2297876218699
